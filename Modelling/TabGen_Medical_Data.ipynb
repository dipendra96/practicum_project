# %% [markdown]
# **Installing and importing necessary libraries**

# %%
# %%capture
# !pip install be-great
# !pip install openpyxl

# %%
# from be_great import GReaT
import pandas as pd
import torch
import xlrd
from openpyxl import load_workbook
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Capgemini-Practicum
# Out:
# /content/drive/MyDrive/Capgemini-Practicum

# %%
# %ls
# Out:
#  be_great/   ModelDataCheckpoints/   Proposal_Research.docx
#  Dataset/    Notebooks/             'Relevant Papers'/

# %%
# !git clone https://github.com/kathrinse/be_great.git

# %%
# %cd be_great
# Out:
# /content/drive/MyDrive/Capgemini-Practicum/be_great

# %%
# !pip install -r requirements.txt --quiet

# %% [markdown]
# **Loading the medical claims data and data dictionary file**

# %%
## Reading in Schema file - Medical Claims
file_path = '/content/drive/MyDrive/Capgemini-Practicum/Dataset/Data Dictionary Medical Claims.xlsx'
df_medical_schema = pd.read_excel(file_path, skiprows=1)

# %%
column_indices_to_keep=[3,13,16,18,19,20,21,23,24,25,31,32,33,36,49,52,67,68,75,76,80]
##adjusting for indices
column_indices_to_keep=[i-3 for i in column_indices_to_keep]

# %%
df_medical_schema=df_medical_schema.iloc[column_indices_to_keep].reset_index(drop=True)

# %%
dtypes = {'_c21': 'str', '_c61': 'str','_c13':'str'}
df_medical_data = pd.read_csv("drive/MyDrive/Capgemini-Practicum/Dataset/medical_claims.csv.gz", usecols=column_indices_to_keep,dtype=dtypes)
print(df_medical_data.shape)
# Out:
# (8092330, 21)

# %%
df_medical_data.columns=list(df_medical_schema['Field'])

# %%
df_medical_data=df_medical_data[df_medical_data['Member Life ID']!=-1].reset_index(drop=True)

# %%
df_medical_data.columns
# Out:
# Index(['Member Life ID', 'Gender Code', 'Subscriber Zip Code',
#        'Claim Type Code', 'Claim Number', 'Line #', 'Claim Disposition',
#        'Network Indicator', 'Bill Type', 'Internal Provider Number',
#        'Place of Service Code', 'Type of Service Code',
#        'Current Procedural Terminology', 'Revenue Codes',
#        'Primary Diagnosis Code-ICD10', 'ICD10 Surgical Procedure Code 1',
#        'Line Service From Date', 'Line Service thru Date', '# of Services',
#        'Billed Amount', 'Paid Amount'],
#       dtype='object')

# %%
df_medical_data['Line Service From Date']=pd.to_datetime(df_medical_data['Line Service From Date'])
df_medical_data['Line Service thru Date']=pd.to_datetime(df_medical_data['Line Service thru Date'])

# %%
# df_medical_data=df_medical_data[df_medical_data['Line Service From Date'].dt.year==2018][['Member Life ID','Gender Code','Claim Type Code','Claim Number','Line #','Current Procedural Terminology',\
#                                                                           'Primary Diagnosis Code-ICD10','Line Service From Date', 'Line Service thru Date','Billed Amount', 'Paid Amount']].reset_index(drop=True)

# %%
df_medical_data=df_medical_data[['Member Life ID','Gender Code','Claim Type Code','Claim Number','Line #','Current Procedural Terminology',\
                                                                          'Primary Diagnosis Code-ICD10','Line Service From Date', 'Line Service thru Date','Billed Amount', 'Paid Amount']].reset_index(drop=True)

# %%
df_medical_data[df_medical_data['Claim Number']=='801960759500']
# Out:
#         Member Life ID Gender Code Claim Type Code  Claim Number  Line #  \
# 137081         3269408           M               P  801960759500       4
# 154970         3269408           M               P  801960759500       3
# 171966         3269408           M               P  801960759500       1
# 176372         3269408           M               P  801960759500       2
#
#        Current Procedural Terminology Primary Diagnosis Code-ICD10  \
# 137081                          97140                        M9904
# 154970                          97012                        M9904
# 171966                          98943                        M9904
# 176372                          98941                        M9904
#
#        Line Service From Date Line Service thru Date  Billed Amount  \
# 137081             2018-01-12             2018-01-12           45.0
# 154970             2018-01-12             2018-01-12           55.0
# 171966             2018-01-12             2018-01-12           45.0
# 176372             2018-01-12             2018-01-12           50.0
#
#         Paid Amount
# 137081        18.14
# 154970        12.15
# 171966         0.00
# 176372        22.14

# %%
df_medical_data[df_medical_data['Member Life ID']==3269408]['Claim Number'].nunique()
# Out:
# 83

# %%
df_medical_data=df_medical_data.sort_values(by=['Member Life ID','Claim Number', 'Billed Amount'], ascending=[True,True, False]).drop_duplicates(subset='Claim Number', keep='first')[['Member Life ID','Gender Code',\
                                                                                                                                                                                       'Claim Number','Current Procedural Terminology',\
                                                                          'Primary Diagnosis Code-ICD10','Line Service From Date', 'Line Service thru Date','Billed Amount', 'Paid Amount']].reset_index(drop=True)

# %% [markdown]
# **Plotting the distribution of # claims for each patient**

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.histplot(df_medical_data.groupby(by='Member Life ID',as_index=False)['Claim Number'].nunique()['Claim Number'])
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# *Subsetting the dataset for patients with 3 claims, can be done for any number of claims at the cost of increased input context*

# %%
df_subset=df_medical_data.groupby(by='Member Life ID',as_index=False)['Claim Number'].nunique().rename(columns={'Claim Number':'num_unique_claims'})
member_id_to_keep=list(df_subset[df_subset['num_unique_claims']==3]['Member Life ID'].unique())
df_medical_data_subset=df_medical_data[df_medical_data['Member Life ID'].isin(member_id_to_keep)].reset_index(drop=True)

# %%
len(member_id_to_keep)
# Out:
# 4521

# %%
# df_subset=df_medical_data.groupby(by='Member Life ID',as_index=False)['Claim Number'].nunique().rename(columns={'Claim Number':'num_unique_claims'})
# member_id_to_keep=list(df_subset[df_subset['num_unique_claims']<=5]['Member Life ID'].unique())
# df_medical_data_subset=df_medical_data[df_medical_data['Member Life ID'].isin(member_id_to_keep)].reset_index(drop=True)

# %%
df_medical_data_subset['Patient ID']=df_medical_data_subset['Member Life ID'].map(dict(zip(df_medical_data_subset['Member Life ID'].unique(),range((df_medical_data_subset['Member Life ID'].nunique())))))

# %%
df_medical_data_subset.columns=[x.replace(' ','_').lower() for x in df_medical_data_subset.columns]

# %%
df_medical_data_subset
# Out:
#        member_life_id gender_code     claim_number  \
# 0                3838           F     710270216200
# 1                3838           F     719570192800
# 2                3838           F     727770451700
# 3                7054           M  026182193595900
# 4                7054           M  026182273878400
# ...               ...         ...              ...
# 13558        38148316           M     A084P0416900
# 13559        38148316           M     A189I0309400
# 13560        38541263           M     731418296500
# 13561        38541263           M     831919010100
# 13562        38541263           M     832414390100
#
#       current_procedural_terminology primary_diagnosis_code-icd10  \
# 0                              90833                         F341
# 1                              90833                         F341
# 2                              90833                         F341
# 3                              12002                      S61212A
# 4                              99211                      S61212D
# ...                              ...                          ...
# 13558                          99204                         P599
# 13559                              *                        Z3800
# 13560                          99393                       Z00129
# 13561                          99393                       Z00129
# 13562                          99202                         L309
#
#       line_service_from_date line_service_thru_date  billed_amount  \
# 0                 2017-03-31             2017-03-31          100.0
# 1                 2017-06-09             2017-06-09          100.0
# 2                 2017-09-01             2017-09-01          100.0
# 3                 2018-07-26             2018-07-26          337.0
# 4                 2018-08-05             2018-08-05           62.0
# ...                      ...                    ...            ...
# 13558             2017-04-18             2017-04-18          210.0
# 13559             2017-04-12             2017-04-13         2600.0
# 13560             2017-11-07             2017-11-07          175.0
# 13561             2018-11-12             2018-11-12          175.0
# 13562             2018-11-16             2018-11-16          147.0
#
#        paid_amount  patient_id
# 0             0.00           0
# 1             0.00           0
# 2             0.00           0
# 3           103.96           1
# 4            23.65           1
# ...            ...         ...
# 13558         0.00        4519
# 13559         0.00        4519
# 13560        68.07        4520
# 13561        68.07        4520
# 13562        84.50        4520
#
# [13563 rows x 10 columns]

# %%
df_medical_data_subset=df_medical_data_subset[['member_life_id','gender_code',
       'current_procedural_terminology', 'primary_diagnosis_code-icd10',
       'line_service_from_date', 'line_service_thru_date', 'billed_amount',
       'paid_amount']].rename(columns={'member_life_id':'patient_id','current_procedural_terminology':'cpt_code','primary_diagnosis_code-icd10':'primary_diagnosis_code','line_service_from_date':'visit_start_date','line_service_thru_date':'visit_end_date'})

# %%
df_medical_data_subset['visit_start_date']=df_medical_data_subset['visit_start_date'].astype(str)
df_medical_data_subset['visit_end_date']=df_medical_data_subset['visit_end_date'].astype(str)

# %% [markdown]
# **Function to Format Input prompts to capture time dependance**

# %%
import pandas as pd

# Assuming we have a dataframe 'df' with the necessary columns.
# The function to be applied across the dataframe would look something like this:

def format_visit_information(row):
    # Extract the column names except 'patient_id' and 'gender_code'
    column_names = row.index.tolist()
    # remove_list=[]
    column_names.remove('patient_id')
    column_names.remove('gender_code')

    # Build the visit information string with column names and values
    visit_info = ", ".join(f"{col} is {row[col]}" for col in column_names)
    return f"{visit_info}"

# Applying the function to each row of the DataFrame and assigning the result to a new 'visit_info' column
# df['visit_info'] = df.apply(format_visit_information, axis=1)

# Now, assuming the dataframe contains multiple patients and we want to group by 'patient_id' and 'gender_code'
# and then apply the visit information formatting to each group.

# Modified function to concatenate visit information with each visit on a new line
def concatenate_visits(group):
    visit_details = group.apply(format_visit_information, axis=1).tolist()
    return "\n".join(f"<visit_{i+1}> : {details}" for i, details in enumerate(visit_details))

# Group by 'patient_id' and 'gender_code' and apply the concatenation function
# grouped_info = df.groupby(['patient_id', 'gender_code']).apply(concatenate_visits).reset_index(name='visit_info')

# The 'grouped_info' DataFrame will now have a summary string for each patient.

# %% [markdown]
# **Transformed Data View**

# %%
grouped_info = df_medical_data_subset.groupby(['patient_id', 'gender_code']).apply(concatenate_visits).reset_index(name='visit_info')

grouped_info
# Out:
#       patient_id gender_code  \
# 0           3838           F
# 1           7054           M
# 2           9296           M
# 3          12466           M
# 4          12937           M
# ...          ...         ...
# 4518    36162468           F
# 4519    36179853           M
# 4520    36222904           M
# 4521    38148316           M
# 4522    38541263           M
#
#                                              visit_info
# 0     <visit_1> : cpt_code is 90833, primary_diagnos...
# 1     <visit_1> : cpt_code is 12002, primary_diagnos...
# 2     <visit_1> : cpt_code is 99213, primary_diagnos...
# 3     <visit_1> : cpt_code is 99213, primary_diagnos...
# 4     <visit_1> : cpt_code is 99395, primary_diagnos...
# ...                                                 ...
# 4518  <visit_1> : cpt_code is 99204, primary_diagnos...
# 4519  <visit_1> : cpt_code is 92587, primary_diagnos...
# 4520  <visit_1> : cpt_code is 99464, primary_diagnos...
# 4521  <visit_1> : cpt_code is 99391, primary_diagnos...
# 4522  <visit_1> : cpt_code is 99393, primary_diagnos...
#
# [4523 rows x 3 columns]

# %%
grouped_info.to_csv('drive/MyDrive/Capgemini-Practicum/Dataset/patient_visit_info_3_visits.csv')

# %%
(grouped_info.loc[1,'visit_info'])
# Out:
# '<visit_1> : cpt_code is 12002, primary_diagnosis_code is S61212A, visit_start_date is 2018-07-26, visit_end_date is 2018-07-26, billed_amount is 337.0, paid_amount is 103.96\n<visit_2> : cpt_code is 99211, primary_diagnosis_code is S61212D, visit_start_date is 2018-08-05, visit_end_date is 2018-08-05, billed_amount is 62.0, paid_amount is 23.65\n<visit_3> : cpt_code is 92014, primary_diagnosis_code is H5203, visit_start_date is 2017-07-11, visit_end_date is 2017-07-11, billed_amount is 145.0, paid_amount is 72.76'

# %% [markdown]
# ***Transforming all the details into a single row with multiple columns leveraging the above transformation function***

# %%
import pandas as pd
import re
# Function to extract and transform the data
def extract_and_transform(row):
    # Find all the visits
    visits = re.findall(r"<(visit_\d+)> : (.+?)\s*(?=<visit_\d+>|$)", row)

    # Dictionary to hold the extracted data
    extracted_data = {}

    for visit in visits:
        visit_name, visit_data = visit
        # Find all the key-value pairs in the visit
        key_values = re.findall(r"(\w+) is ([\w\d.-]+)", visit_data)
        for key, value in key_values:
            # Construct the new column name
            column_name = f"{visit_name}_{key}"
            extracted_data[column_name] = value

    return extracted_data

# Apply the function to each row and create a new DataFrame

extracted_rows = grouped_info['visit_info'].apply(extract_and_transform)
df_transformed = pd.concat([grouped_info[['patient_id','gender_code']],pd.DataFrame(extracted_rows.tolist())],axis=1)

df_transformed.head()
# Out:
#    patient_id gender_code visit_1_cpt_code visit_1_primary_diagnosis_code  \
# 0        3838           F            90833                           F341
# 1        7054           M            12002                        S61212A
# 2        9296           M            99213                         M25511
# 3       12466           M            99213                         Z98890
# 4       12937           M            99395                          Z0000
#
#   visit_1_visit_start_date visit_1_visit_end_date visit_1_billed_amount  \
# 0               2017-03-31             2017-03-31                 100.0
# 1               2018-07-26             2018-07-26                 337.0
# 2               2017-02-13             2017-02-13                  75.0
# 3               2017-01-09             2017-01-09                 160.0
# 4               2017-02-24             2017-02-24                 135.0
#
#   visit_1_paid_amount visit_2_cpt_code visit_2_primary_diagnosis_code  \
# 0                 0.0            90833                           F341
# 1              103.96            99211                        S61212D
# 2                 0.0            97811                         M25511
# 3               44.36            V2020                          H5210
# 4              122.35            99395                          Z0000
#
#   visit_2_visit_start_date visit_2_visit_end_date visit_2_billed_amount  \
# 0               2017-06-09             2017-06-09                 100.0
# 1               2018-08-05             2018-08-05                  62.0
# 2               2017-02-20             2017-02-20                 105.0
# 3               2017-05-06             2017-05-06                 150.0
# 4               2017-02-24             2017-02-24                -135.0
#
#   visit_2_paid_amount visit_3_cpt_code visit_3_primary_diagnosis_code  \
# 0                 0.0            90833                           F341
# 1               23.65            92014                          H5203
# 2                 0.0            97811                         M25512
# 3                 0.0            99213                           J020
# 4             -122.35            99395                          Z0000
#
#   visit_3_visit_start_date visit_3_visit_end_date visit_3_billed_amount  \
# 0               2017-09-01             2017-09-01                 100.0
# 1               2017-07-11             2017-07-11                 145.0
# 2               2017-02-27             2017-02-27                 105.0
# 3               2017-06-09             2017-06-09                 144.0
# 4               2017-02-24             2017-02-24                 135.0
#
#   visit_3_paid_amount
# 0                 0.0
# 1               72.76
# 2                 0.0
# 3               59.36
# 4                 0.0

# %%
df_transformed.shape
# Out:
# (4523, 20)

# %% [markdown]
# **Prompt to Transform grouoed_info into a single prompt for model input**

# %%
def prompt(row):
  column_names = row.index.tolist()
  prompt = ", ".join(f"{col} is {row[col]}" for col in column_names[:-1])
  prompt+=f", {column_names[-1]} is\n{row[column_names[-1]]}"
  return f"{prompt}"

# %%
print(grouped_info.apply(lambda x:prompt(x), axis=1).iloc[1])
# Out:
# patient_id is 470, gender_code is M, visit_info is
# <visit_1> : cpt_code is T2022, primary_diagnosis_code is R6889, visit_start_date is 2018-01-31, visit_end_date is 2018-01-31, billed_amount is 395.0, paid_amount is 395.0
# <visit_2> : cpt_code is T2023, primary_diagnosis_code is F322, visit_start_date is 2018-01-12, visit_end_date is 2018-01-12, billed_amount is 390.0, paid_amount is 390.0
# <visit_3> : cpt_code is 99214, primary_diagnosis_code is F331, visit_start_date is 2018-05-16, visit_end_date is 2018-05-16, billed_amount is 256.0, paid_amount is 169.77

# %%
df_transformed['patient_id']=df_transformed['patient_id'].map({k:'p_' + str(v) for k,v in dict(zip(df_transformed['patient_id'],range(df_transformed.shape[0]))).items()})

# %%
df_transformed
# Out:
#      patient_id gender_code visit_1_cpt_code visit_1_primary_diagnosis_code  \
# 0           p_0           F            90833                           F341
# 1           p_1           M            12002                        S61212A
# 2           p_2           M            99213                         M25511
# 3           p_3           M            99213                         Z98890
# 4           p_4           M            99395                          Z0000
# ...         ...         ...              ...                            ...
# 4518     p_4518           F            99204                           P925
# 4519     p_4519           M            92587                          Z3800
# 4520     p_4520           M            99464                          Z3801
# 4521     p_4521           M            99391                         Z00111
# 4522     p_4522           M            99393                         Z00129
#
#      visit_1_visit_start_date visit_1_visit_end_date visit_1_billed_amount  \
# 0                  2017-03-31             2017-03-31                 100.0
# 1                  2018-07-26             2018-07-26                 337.0
# 2                  2017-02-13             2017-02-13                  75.0
# 3                  2017-01-09             2017-01-09                 160.0
# 4                  2017-02-24             2017-02-24                 135.0
# ...                       ...                    ...                   ...
# 4518               2018-12-10             2018-12-10                 250.0
# 4519               2018-12-29             2018-12-29                 275.0
# 4520               2018-12-28             2018-12-28                 163.0
# 4521               2017-05-02             2017-05-02                 160.0
# 4522               2017-11-07             2017-11-07                 175.0
#
#      visit_1_paid_amount visit_2_cpt_code visit_2_primary_diagnosis_code  \
# 0                    0.0            90833                           F341
# 1                 103.96            99211                        S61212D
# 2                    0.0            97811                         M25511
# 3                  44.36            V2020                          H5210
# 4                 122.35            99395                          Z0000
# ...                  ...              ...                            ...
# 4518              115.35            99391                         Z00111
# 4519                 0.0            99238                          Z3800
# 4520               62.77            99238                          Z3801
# 4521               99.82            99204                           P599
# 4522               68.07            99393                         Z00129
#
#      visit_2_visit_start_date visit_2_visit_end_date visit_2_billed_amount  \
# 0                  2017-06-09             2017-06-09                 100.0
# 1                  2018-08-05             2018-08-05                  62.0
# 2                  2017-02-20             2017-02-20                 105.0
# 3                  2017-05-06             2017-05-06                 150.0
# 4                  2017-02-24             2017-02-24                -135.0
# ...                       ...                    ...                   ...
# 4518               2018-12-21             2018-12-21                 150.0
# 4519               2018-12-29             2018-12-29                 189.0
# 4520               2018-12-31             2018-12-31                 158.0
# 4521               2017-04-18             2017-04-18                 210.0
# 4522               2018-11-12             2018-11-12                 175.0
#
#      visit_2_paid_amount visit_3_cpt_code visit_3_primary_diagnosis_code  \
# 0                    0.0            90833                           F341
# 1                  23.65            92014                          H5203
# 2                    0.0            97811                         M25512
# 3                    0.0            99213                           J020
# 4                -122.35            99395                          Z0000
# ...                  ...              ...                            ...
# 4518                74.4            99460                          Z3800
# 4519               90.06            99460                          Z3800
# 4520               57.64            99460                          Z3801
# 4521                 0.0              NaN                          Z3800
# 4522               68.07            99202                           L309
#
#      visit_3_visit_start_date visit_3_visit_end_date visit_3_billed_amount  \
# 0                  2017-09-01             2017-09-01                 100.0
# 1                  2017-07-11             2017-07-11                 145.0
# 2                  2017-02-27             2017-02-27                 105.0
# 3                  2017-06-09             2017-06-09                 144.0
# 4                  2017-02-24             2017-02-24                 135.0
# ...                       ...                    ...                   ...
# 4518               2018-12-07             2018-12-07                 637.0
# 4519               2018-12-28             2018-12-28                 285.0
# 4520               2018-12-28             2018-12-28                 275.0
# 4521               2017-04-12             2017-04-13                2600.0
# 4522               2018-11-16             2018-11-16                 147.0
#
#      visit_3_paid_amount
# 0                    0.0
# 1                  72.76
# 2                    0.0
# 3                  59.36
# 4                    0.0
# ...                  ...
# 4518              128.85
# 4519              124.32
# 4520               81.29
# 4521                 0.0
# 4522                84.5
#
# [4523 rows x 20 columns]

# %% [markdown]
# **Saving the Transformed Data File**

# %%
# df_transformed.to_csv('/content/drive/MyDrive/Capgemini-Practicum/Dataset/df_transformed_v0.csv',index=False)

# %% [markdown]
# **Loading in the transformed patient level data**

# %%
df_transformed=pd.read_csv('/content/drive/MyDrive/Capgemini-Practicum/Dataset/df_transformed_v0.csv',index_col=False)
df_transformed.head()
# Out:
#   patient_id gender_code visit_1_cpt_code visit_1_primary_diagnosis_code  \
# 0        p_0           F            90833                           F341
# 1        p_1           M            12002                        S61212A
# 2        p_2           M            99213                         M25511
# 3        p_3           M            99213                         Z98890
# 4        p_4           M            99395                          Z0000
#
#   visit_1_visit_start_date visit_1_visit_end_date  visit_1_billed_amount  \
# 0               2017-03-31             2017-03-31                  100.0
# 1               2018-07-26             2018-07-26                  337.0
# 2               2017-02-13             2017-02-13                   75.0
# 3               2017-01-09             2017-01-09                  160.0
# 4               2017-02-24             2017-02-24                  135.0
#
#    visit_1_paid_amount visit_2_cpt_code visit_2_primary_diagnosis_code  \
# 0                 0.00            90833                           F341
# 1               103.96            99211                        S61212D
# 2                 0.00            97811                         M25511
# 3                44.36            V2020                          H5210
# 4               122.35            99395                          Z0000
#
#   visit_2_visit_start_date visit_2_visit_end_date  visit_2_billed_amount  \
# 0               2017-06-09             2017-06-09                  100.0
# 1               2018-08-05             2018-08-05                   62.0
# 2               2017-02-20             2017-02-20                  105.0
# 3               2017-05-06             2017-05-06                  150.0
# 4               2017-02-24             2017-02-24                 -135.0
#
#    visit_2_paid_amount visit_3_cpt_code visit_3_primary_diagnosis_code  \
# 0                 0.00            90833                           F341
# 1                23.65            92014                          H5203
# 2                 0.00            97811                         M25512
# 3                 0.00            99213                           J020
# 4              -122.35            99395                          Z0000
#
#   visit_3_visit_start_date visit_3_visit_end_date  visit_3_billed_amount  \
# 0               2017-09-01             2017-09-01                  100.0
# 1               2017-07-11             2017-07-11                  145.0
# 2               2017-02-27             2017-02-27                  105.0
# 3               2017-06-09             2017-06-09                  144.0
# 4               2017-02-24             2017-02-24                  135.0
#
#    visit_3_paid_amount
# 0                 0.00
# 1                72.76
# 2                 0.00
# 3                59.36
# 4                 0.00

# %%
df_transformed.shape
# Out:
# (4523, 20)

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU is not available; using CPU")

torch.cuda.empty_cache()
# Out:
# GPU is available

# %% [markdown]
# **Loading in GReaT library for Modeling Real Data and Generate Synthetic Data**

# %%
from be_great import GReaT

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install peft --quiet

# %%
# !pip install loralib==0.1.1 --quiet

# %% [markdown]
# **Function call to initiate the language model**

# %%
gpt2_large_model = GReaT(llm='gpt2-large', batch_size=4, epochs=2,
              experiment_dir="/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/trainer_medical_transformed",\
                   efficient_finetuning="lora",learning_rate=1e-3,save_steps=10000)

# gpt2_large_model = GReaT(llm='gpt2-large', batch_size=4, epochs=2,
#               experiment_dir="/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/trainer_medical_transformed_gpt2_large",save_steps=200)
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# trainable params: 2,949,120 || all params: 776,979,200 || trainable%: 0.3795622842928099
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:136: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/model.py:311: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %% [markdown]
# **Fitting the language model - Finetuning through labeled transformation**

# %%
gpt2_large_model.fit(df_transformed.sample(1000))
# Out:
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 12:16, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.610300</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# **Saving and Loading the Finetuned Language Model Checkpoint**

# %%
##Save the entire model
# torch.save(gpt2_large_model, '/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_large_model.pth')
## Loading the saved model
gpt2_large_model=torch.load('/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_large_model.pth')

# %%
# Out:
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 01:09, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
##Save the entire model
torch.save(gpt2_large_model, '/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_large_model.pth')
## Loading the saved model
gpt2_large_model=torch.load('/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_large_model.pth')

# %%
# Save the entire model
# torch.save(gpt2_model, '/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_model_baseline.pth')
## Loading the saved model
gpt2_model=torch.load('/content/drive/MyDrive/Capgemini-Practicum/ModelDataCheckpoints/gpt2_model_baseline.pth')

# %%
# synthetic_data_gpt2_large=gpt2_large_model.sample(100,max_length=512)

# %%
synthetic_data_baseline = gpt2_model.sample(n_samples=1000,max_length=512)
# Out:
# 1058it [01:53,  9.34it/s]

# %%
synthetic_data_baseline.head()
# Out:
#   patient_id gender_code visit_1_cpt_code visit_1_primary_diagnosis_code  \
# 0     p_2608           M            99392                         Z01419
# 1       p_17           M            99213                           J209
# 2     p_3603           F            90651                         Z00129
# 3     p_2281           M            99214                          R5383
# 4     p_2345           M            99214                         Z00129
#
#   visit_1_visit_start_date visit_1_visit_end_date  visit_1_billed_amount  \
# 0               2017-06-17             2017-06-17                  254.0
# 1               2017-11-07             2017-11-07                  150.0
# 2               2017-03-26             2017-03-26                   60.0
# 3               2017-03-26             2017-03-26                  110.0
# 4               2018-07-31             2018-07-31                  212.0
#
#    visit_1_paid_amount visit_2_cpt_code visit_2_primary_diagnosis_code  \
# 0               124.88            99392                         Z01419
# 1                 0.00            99213                           J209
# 2                53.59            99214                            Z23
# 3                 0.00            99213                           E782
# 4                 0.00            99214                         Z00129
#
#   visit_2_visit_start_date visit_2_visit_end_date  visit_2_billed_amount  \
# 0               2017-07-30             2017-07-30                  256.0
# 1               2017-11-23             2017-11-23                  150.0
# 2               2018-10-25             2018-10-25                  110.0
# 3               2017-03-26             2017-03-26                  110.0
# 4               2018-07-31             2018-07-31                  212.0
#
#    visit_2_paid_amount visit_3_cpt_code visit_3_primary_diagnosis_code  \
# 0                 0.00            90471                         Z01419
# 1                 0.00            99213                           J209
# 2                80.24            99214                         Z00129
# 3                 0.00            99214                          R5383
# 4                 0.00            99214                          R6889
#
#   visit_3_visit_start_date visit_3_visit_end_date  visit_3_billed_amount  \
# 0               2017-11-13             2017-11-13                   18.0
# 1               2017-11-22             2017-11-22                  150.0
# 2               2018-11-14             2018-11-14                  180.0
# 3               2017-03-26             2017-03-26                  230.0
# 4               2018-07-31             2018-07-31                  212.0
#
#    visit_3_paid_amount
# 0               512.43
# 1               121.37
# 2                89.38
# 3               119.20
# 4                79.26

# %%
synthetic_data_baseline.shape
# Out:
# (1000, 20)

# %% [markdown]
# **Saving the generated synthetic Data**

# %%
synthetic_data_baseline.to_csv('/content/drive/MyDrive/Capgemini-Practicum/Dataset/synthetic_data_baseline_gpt2.csv',index=False)
