# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/Practicum/great/be_great')

# %%
# !pip install be-great peft

# %%
# !pip install -r requirements.txt
# !pip install peft transformers[torch]

# %%
#from be_great.great import *
from be_great import GReaT
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/merged_prompts.csv')
data
# Out:
#        Member Life ID  Gender  Age  \
# 0             1002783    Male   38
# 1            10036469  Female   44
# 2             1004042  Female   29
# 3             1004724  Female   36
# 4            10050141    Male   41
# ...               ...     ...  ...
# 18727          995386  Female   33
# 18728          995711  Female   32
# 18729          995943    Male   34
# 18730         9969950    Male   26
# 18731          997087  Female   32
#
#                                                    Visit
# 0      <visit_1> : Claim Type is P, CPT Code is 99214...
# 1      <visit_1> : Claim Type is P, CPT Code is 99395...
# 2      <visit_1> : Claim Type is P, CPT Code is 99395...
# 3      <visit_1> : Claim Type is P, CPT Code is 99201...
# 4      <visit_1> : Claim Type is P, CPT Code is 99214...
# ...                                                  ...
# 18727  <visit_1> : Claim Type is P, CPT Code is 71046...
# 18728  <visit_1> : Claim Type is P, CPT Code is 81003...
# ...

# %%
data = data.drop('Member Life ID', axis=1)

# %%
model = GReaT(llm='distilgpt2', batch_size=4, epochs=5, efficient_finetuning='lora')
model.fit(data)

# %%
model.sample(n_samples=100, max_length=600) #  Change num samples if needed
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
